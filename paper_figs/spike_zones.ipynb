# %%
from aoespy import *
import xarray as xr
dir='/nobackupp27/afahad/exp/'
data='/nobackupp27/afahad/project/initialization_shock/data/'
# Out:
# /home6/afahad/.local/lib/python3.9/site-packages/aoespy.py:19: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
RP416=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0416/holding/geosgcm_surf/200504/*surf*200504*z.nc4')
RP421=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0421/holding/geosgcm_surf/200504/*surf*200504*z.nc4')
RP426=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0426/holding/geosgcm_surf/200504/*surf*200504*z.nc4')
RP506=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0506/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
RP511=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0511/holding/geosgcm_surf/200505/*surf*200505*z.nc4')

# %%
RP4162=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0416/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
RP4212=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0421/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
RP4262=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0426/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
RP5062=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0506/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
RP5112=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0511/holding/geosgcm_surf/200506/*surf*200506*z.nc4')

# %%
RP4163=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0416/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
RP4213=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0421/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
RP4263=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0426/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
RP5063=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0506/holding/geosgcm_surf/200507/*surf*200507*z.nc4')
RP5113=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_RP0511/holding/geosgcm_surf/200507/*surf*200507*z.nc4')

# %%
RP4161=xr.concat([RP416,RP4162,RP4163],dim='time')
RP4211=xr.concat([RP421,RP4212,RP4213],dim='time')
RP426=xr.concat([RP426,RP4262,RP4263],dim='time')
RP506=xr.concat([RP506,RP5062,RP5063],dim='time')
RP511=xr.concat([RP511,RP5112,RP5113],dim='time')

# %%
RP416P=(RP4161.PRECTOT.compute())*86400
RP421P=(RP4211.PRECTOT.compute())*86400
RP426P=(RP426.PRECTOT.compute())*86400
RP506P=(RP506.PRECTOT.compute())*86400
RP511P=(RP511.PRECTOT.compute())*86400

# %%
ME416=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0416/holding/geosgcm_surf/200504/*surf*200504*z.nc4')
ME421=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0421/holding/geosgcm_surf/200504/*surf*200504*z.nc4')
ME426=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0426/holding/geosgcm_surf/200504/*surf*200504*z.nc4')
ME506=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0506/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
ME511=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0511/holding/geosgcm_surf/200505/*surf*200505*z.nc4')

ME4162=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0416/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
ME4212=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0421/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
ME4262=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0426/holding/geosgcm_surf/200505/*surf*200505*z.nc4')
ME5062=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0506/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
ME5112=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0511/holding/geosgcm_surf/200506/*surf*200506*z.nc4')

ME4163=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0416/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
ME4213=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0421/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
ME4263=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0426/holding/geosgcm_surf/200506/*surf*200506*z.nc4')
ME5063=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0506/holding/geosgcm_surf/200507/*surf*200507*z.nc4')
ME5113=xr.open_mfdataset('/nobackupp27/afahad/exp/IAU_exp/GEOSMIT_ME0511/holding/geosgcm_surf/200507/*surf*200507*z.nc4')


ME4161=xr.concat([ME416,ME4162,ME4163],dim='time')
ME4211=xr.concat([ME421,ME4212,ME4213],dim='time')
ME426=xr.concat([ME426,ME4262,ME4263],dim='time')
ME506=xr.concat([ME506,ME5062,ME5063],dim='time')
ME511=xr.concat([ME511,ME5112,ME5113],dim='time')


ME416P=(ME4161.PRECTOT.compute())*86400
ME421P=(ME4211.PRECTOT.compute())*86400
ME426P=(ME426.PRECTOT.compute())*86400
ME506P=(ME506.PRECTOT.compute())*86400
ME511P=(ME511.PRECTOT.compute())*86400

# %%
ME416C=zeros((181,360,len(ME416P)))
ME421C=zeros((181,360,len(ME421P)))
ME426C=zeros((181,360,len(ME426P)))
ME506C=zeros((181,360,len(ME506P)))
ME511C=zeros((181,360,len(ME511P)))

# %%
ME416P=(ME4161.PRECTOT.compute())*86400
ME421P=(ME4211.PRECTOT.compute())*86400
RP416P=(RP4161.PRECTOT.compute())*86400
RP421P=(RP4211.PRECTOT.compute())*86400
