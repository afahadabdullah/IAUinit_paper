# %%
import os 
# Path to your directory with files
directory = "/nobackupp27/afahad/exp/GEOSMIT_RP0506/rs/"

for filename in os.listdir(directory):
    old_path = os.path.join(directory, filename)
    
    # Skip if it's not a file
    if not os.path.isfile(old_path):
        continue
    
    # Split on dots
    parts = filename.split(".")
    if len(parts) >= 2:
        new_name = parts[1]  # Take the part between the first and second dot
        new_path = os.path.join(directory, new_name)
        
        # Rename the file
        os.rename(old_path, new_path)
        print(f"Renamed: {filename} -> {new_name}")
    else:
        print(f"Skipping (no two dots): {filename}")
# Out:
# Renamed: GEOSMIT_RP0506.landice_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> landice_internal_rst
# Renamed: GEOSMIT_RP0506.irrad_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> irrad_internal_rst
# Renamed: GEOSMIT_RP0506.cabr_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> cabr_internal_rst
# Renamed: GEOSMIT_RP0506.surf_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> surf_import_rst
# Renamed: GEOSMIT_RP0506.tr_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> tr_import_rst
# Renamed: GEOSMIT_RP0506.hemco_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> hemco_import_rst
# Renamed: GEOSMIT_RP0506.caoc_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> caoc_internal_rst
# Renamed: GEOSMIT_RP0506.aiau_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> aiau_import_rst
# Renamed: GEOSMIT_RP0506.gocart_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> gocart_import_rst
# Renamed: GEOSMIT_RP0506.du_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> du_internal_rst
# Renamed: GEOSMIT_RP0506.catch_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> catch_internal_rst
# Renamed: GEOSMIT_RP0506.gwd_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> gwd_internal_rst
# Renamed: GEOSMIT_RP0506.openwater_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> openwater_internal_rst
# Renamed: GEOSMIT_RP0506.turb_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> turb_import_rst
# Renamed: GEOSMIT_RP0506.fvcore_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> fvcore_internal_rst
# Renamed: GEOSMIT_RP0506.saltwater_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> saltwater_import_rst
# Renamed: GEOSMIT_RP0506.moist_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> moist_internal_rst
# Renamed: GEOSMIT_RP0506.gwd_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> gwd_import_rst
# Renamed: GEOSMIT_RP0506.ni_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> ni_internal_rst
# Renamed: GEOSMIT_RP0506.ocean_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> ocean_internal_rst
# Renamed: GEOSMIT_RP0506.seaicethermo_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> seaicethermo_internal_rst
# Renamed: GEOSMIT_RP0506.hemco_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> hemco_internal_rst
# Renamed: GEOSMIT_RP0506.lake_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> lake_internal_rst
# Renamed: GEOSMIT_RP0506.moist_import_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> moist_import_rst
# Renamed: restarts.e20050506_00z.tar -> e20050506_00z
# Renamed: GEOSMIT_RP0506.pchem_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> pchem_internal_rst
# Renamed: GEOSMIT_RP0506.cabc_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> cabc_internal_rst
# Renamed: GEOSMIT_RP0506.ss_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> ss_internal_rst
# Renamed: GEOSMIT_RP0506.gocart_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> gocart_internal_rst
# Renamed: GEOSMIT_RP0506.solar_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> solar_internal_rst
# Renamed: GEOSMIT_RP0506.achem_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> achem_internal_rst
# Renamed: GEOSMIT_RP0506.su_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> su_internal_rst
# Renamed: GEOSMIT_RP0506.tr_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> tr_internal_rst
# Renamed: GEOSMIT_RP0506.turb_internal_rst.e20050506_00z.GEOSgcm-v11.1.1.a90x540_o5400x15_CF0090x6C_DE0360xPE0180 -> turb_internal_rst
