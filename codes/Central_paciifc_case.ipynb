# %%
from aoespy import *
import xarray as xr
dir='/nobackupp27/afahad/exp/'
data='/nobackupp27/afahad/exp/script_replay_AGU/data/'
# Out:
# /home6/afahad/.local/lib/python3.9/site-packages/aoespy.py:19: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
RP506=xr.open_mfdataset('/nobackupp27/afahad/exp/GEOSMIT_RP0506/holding/geosgcm_surf/200506/*surf*200506*z.nc4').sel(time=slice('2005-06-01','2005-06-10'))
ME506=xr.open_mfdataset('/nobackupp27/afahad/exp/GEOSMIT_ME0506/holding/geosgcm_surf/200506/*surf*200506*z.nc4').sel(time=slice('2005-06-01','2005-06-10'))

# %%
RP506P=(RP506.PRECTOT.compute())*86400
ME506P=(ME506.PRECTOT.compute())*86400

# %%
RP506CP=(RP506.CNPRCP.compute())*86400
ME506CP=(ME506.CNPRCP.compute())*86400

# %%
RP506T=(RP506.TS.compute())
ME506T=(ME506.TS.compute())

RP506Ta=(RP506.TA.compute())
ME506Ta=(ME506.TA.compute())

# %%
RP506S=(RP506.SHFX.compute())
ME506S=(ME506.SHFX.compute())

# %%
RP506E=(RP506.EVAPOUT.compute())
ME506E=(ME506.EVAPOUT.compute())

# %%
RP506E2=(RP506.EVAP.compute())
ME506E2=(ME506.EVAP.compute())

# %%
ticks=[]

for i in range(len(ME506.time)):
    ticks=append(ticks,str(ME506.time.data[i])[5:10])

# %%
x1=-178
x2=-178
y1=2
y2=2

# x1=-127
# x2=-127
# y1=7
# y2=7

f()
plt.subplot(3,3,1)

plt.plot((ME506P).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='blue')
plt.plot((RP506P).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='orange')
plt.title('Total Precipittaion')
plt.xticks(arange(len(ticks))[::20],ticks[::20],fontsize=8);
plt.xlabel('Date (month-day)')
plt.ylabel('mm/day')


plt.subplot(3,3,2)

plt.plot((ME506CP).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='blue')
#plt.plot((RP506CP).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='orange')
plt.plot((ME506S).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='red')
plt.plot((ME506Ta-273.15).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='brown')

plt.title('CNVC Precipittaion')
plt.xticks(arange(len(ticks))[::20],ticks[::20],fontsize=8);
plt.xlabel('Date (month-day)')
plt.ylabel('mm/day')

plt.subplot(3,3,4)
plt.plot((ME506T-273.15).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='red')
plt.plot((ME506Ta-273.15).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='brown')
plt.xticks(arange(len(ticks))[::20],ticks[::20],fontsize=8);
plt.xlabel('Date (month-day)')

plt.subplot(3,3,5)
plt.plot((ME506S).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='brown')
plt.xticks(arange(len(ticks))[::20],ticks[::20],fontsize=8);
plt.xlabel('Date (month-day)')

plt.subplot(3,3,7)
plt.plot((ME506E).sel(lat=slice(y1,y2),lon=slice(x1,x2)).mean(dim=['lon','lat']),color='brown')
plt.xticks(arange(len(ticks))[::20],ticks[::20],fontsize=8);
plt.xlabel('Date (month-day)')
# Out:
# Text(0.5, 0, 'Date (month-day)')
